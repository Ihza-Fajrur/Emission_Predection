# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.naive_bayes import GaussianNB

# %%
df=pd.read_excel('historical_emissions_training.xlsx')
df
# Out:
#        Country Data source                Sector  Gas    Unit     2015  \
# 0    Indonesia        CAIT  Total including LUCF  CO2  MtCO₂e  1574.76
# 1     Malaysia        CAIT  Total including LUCF  CO2  MtCO₂e   124.54
# 2  Philippines        CAIT  Total including LUCF  CO2  MtCO₂e   116.10
# 3      Myanmar        CAIT  Total including LUCF  CO2  MtCO₂e   128.25
# 4      Vietnam        CAIT  Total including LUCF  CO2  MtCO₂e   186.54
# 5    Singapore        CAIT  Total including LUCF  CO2  MtCO₂e    45.45
# 6         Laos        CAIT  Total including LUCF  CO2  MtCO₂e    17.32
# 7       Brunei        CAIT  Total including LUCF  CO2  MtCO₂e     6.35
# 8     Cambodia        CAIT  Total including LUCF  CO2  MtCO₂e    73.51
# 9     Thailand        CAIT  Total including LUCF  CO2  MtCO₂e   263.34
#
#       2014     2013     2012     2011  ...    1999    1998     1997    1996  \
# 0  1539.23  1250.27  1303.87  1285.69  ...  849.42  907.96  1484.56  772.38
# ...

# %%
df.iloc[0,6:9]
# Out:
# 2014    1539.23
# 2013    1250.27
# 2012    1303.87
# Name: 0, dtype: object

# %%
n=6
data=[]
fitur=[]
label=[]
# tuple=()
for i in range(0,len(df.columns)-9):
    data=df.iloc[0,n-1:n+3].values
    # data2=df.iloc[0,n+3:n+4].values
    n+=1
    # x=tuple(data)
    # y=tuple(data2)
    fitur.append(data)
    # label.append(data2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18160/2151630835.py in <module>
#       5 # tuple=()
#       6 for i in range(0,len(df.columns)-9):
# ----> 7     data=float(df.iloc[0,n-1:n+3].values)
#       8     # data2=df.iloc[0,n+3:n+4].values
#       9     n+=1
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
print(fitur)
# Out:
# [array([1574.76, 1539.23, 1250.27, 1303.87], dtype=object), array([1539.23, 1250.27, 1303.87, 1285.69], dtype=object), array([1250.27, 1303.87, 1285.69, 773.92], dtype=object), array([1303.87, 1285.69, 773.92, 1036.71], dtype=object), array([1285.69, 773.92, 1036.71, 731.76], dtype=object), array([773.92, 1036.71, 731.76, 738.57], dtype=object), array([1036.71, 731.76, 738.57, 1152.83], dtype=object), array([731.76, 738.57, 1152.83, 829.93], dtype=object), array([738.57, 1152.83, 829.93, 1031.49], dtype=object), array([1152.83, 829.93, 1031.49, 761.93], dtype=object), array([829.93, 1031.49, 761.93, 1001.39], dtype=object), array([1031.49, 761.93, 1001.39, 631.16], dtype=object), array([761.93, 1001.39, 631.16, 795.62], dtype=object), array([1001.39, 631.16, 795.62, 849.42], dtype=object), array([631.16, 795.62, 849.42, 907.96], dtype=object), array([795.62, 849.42, 907.96, 1484.56], dtype=object), array([849.42, 907.96, 1484.56, 772.38], dtype=object), array([907.96, 1484.56, 772.38
# ...

# %%
lbl=np.array(df.iloc[0,9:31].values)
print(lbl)
# Out:
# [1285.69 773.92 1036.71 731.76 738.57 1152.83 829.93 1031.49 761.93
#  1001.39 631.16 795.62 849.42 907.96 1484.56 772.38 909.21 881.31 869.88
#  855.3 846.23 832.39]

# %%
gnb = GaussianNB()
gnb.fit(fitur, lbl)
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:63: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   return f(*args, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18160/2340200461.py in <module>
#       1 gnb = GaussianNB()
# ----> 2 gnb.fit(fitur, lbl)
#
# c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     207         X, y = self._validate_data(X, y)
#     208         y = column_or_1d(y, warn=True)
# --> 209         return self._partial_fit(X, y, np.unique(y), _refit=True,
# ...
